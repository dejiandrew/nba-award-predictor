# %%
import pandas as pd
import requests
from io import StringIO
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
def get_csv_df(csv_name):
    url = f"https://storage.googleapis.com/nba_award_predictor/nba_data/{csv_name}"

    r = requests.get(url)
    r.raise_for_status()

    csv_text = r.content.decode('utf-8')
    df = pd.read_csv(StringIO(csv_text))
    return df

# %% [markdown]
# # Data Extraction & EDA

# %%
total = get_csv_df("features-overall-weekly.csv")

# %%
"""
full_name, player_id: not features
pow_player_id, player_of_the_week, won_player_of_week: target labels (y data)
all_star_this_season, mvp_this_season, all_nba_first_team_this_season, all_nba_second_team_this_season, all_nba_third_team_this_season: "future data", not determined until end of the season
week_start, pow_conference: redundant, we have season, week, conference
is_win_vs_over_500, opponent_has_all_nba: these were encoders for game entries, our rows are week entries

ask about breakout_score, z_... vs. team_... (is z=z-score and is team features also normalized?)
"""
X = total.drop(columns=['full_name', 'player_id', 'pow_player_id', 'player_of_the_week', 'won_player_of_the_week', 'all_star_this_season', 'mvp_this_season',
 'all_nba_first_team_this_season', 'all_nba_second_team_this_season', 'all_nba_third_team_this_season', 'week_start', 'pow_conference',
 'is_win_vs_over_500', 'opponent_has_all_nba'])

# %%
# Target/y label, 1 if player is winner, 0 otherwise
y = total['won_player_of_the_week']

# %%
# Unlike tree modeling, we do need to hot encode our categorical data: team and conference
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233734 entries, 0 to 233733
# Data columns (total 56 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   team                              233734 non-null  object
#  1   season                            233734 non-null  int64
#  2   week                              233734 non-null  int64
#  3   conference                        233734 non-null  object
#  4   games_played_this_week            233734 non-null  int64
#  5   numMinutes                        233734 non-null  float64
#  6   points                            233734 non-null  float64
#  7   assists                           233734 non-null  float64
#  8   blocks                            233734 non-null  float64
#  9   steals                            233734 non-null  float64
#  10  reboundsTotal                     233734 non-null  float64
#  11  reboundsDefensive                 233734 non-null  float64
#  12  reboundsOffensive                 233734 non-null  float64
#  13  fieldGoalsAttempted               233734 non-null  float64
#  14  fieldGoalsMade                    233734 non-null  float64
#  15  threePointersAttempted            233734 non-null  float64
#  16  threePointersMade                 233734 non-null  float64
#  17  freeThrowsAttempted               233734 non-null  float64
#  18  freeThrowsMade                    233734 non-null  float64
#  19  turnovers                         233734 non-null  float64
#  20  foulsPersonal                     233734 non-null  float64
#  21  plusMinusPoints                   233734 non-null  float64
#  22  wins_this_week                    233734 non-null  float64
#  23  wins_vs_team_with_all_nba_player  233734 non-null  float64
#  24  avg_opp_score                     233734 non-null  float64
#  25  avg_opp_winrate_prior             233734 non-null  float64
#  26  avg_opp_wins_prior                233734 non-null  float64
#  27  avg_opp_losses_prior              233734 non-null  float64
#  28  away_games_prior                  233734 non-null  int64
#  29  away_losses_prior                 233734 non-null  int64
#  30  away_win_streak_prior             233734 non-null  int64
#  31  away_wins_prior                   233734 non-null  int64
#  32  home_games_prior                  233734 non-null  int64
#  33  home_losses_prior                 233734 non-null  int64
#  34  home_win_streak_prior             233734 non-null  int64
#  35  home_wins_prior                   233734 non-null  int64
#  36  losses_prior                      233734 non-null  int64
#  37  wins_vs_over_500_prior            233734 non-null  int64
#  38  team_pts                          233734 non-null  int64
#  39  team_ast                          233734 non-null  int64
#  40  team_blk                          233734 non-null  int64
#  41  team_stl                          233734 non-null  int64
#  42  team_gms                          233734 non-null  int64
#  43  fieldGoalsPercentage              233734 non-null  float64
#  44  threePointersPercentage           233734 non-null  float64
#  45  freeThrowsPercentage              233734 non-null  float64
#  46  points_mean_season                233734 non-null  float64
#  47  points_std_season                 233734 non-null  float64
#  48  assists_mean_season               233734 non-null  float64
#  49  assists_std_season                233734 non-null  float64
#  50  plusMinusPoints_mean_season       233734 non-null  float64
#  51  plusMinusPoints_std_season        233734 non-null  float64
#  52  z_pts                             233734 non-null  float64
#  53  z_ast                             233734 non-null  float64
#  54  z_pm                              233734 non-null  float64
#  55  breakout_score                    233734 non-null  float64
# dtypes: float64(36), int64(18), object(2)
# memory usage: 99.9+ MB

# %% [markdown]
# By one hot encoding our team column, we are going to get 30+ extra columns, one for each of the teams. This will most likely inflate our principal component analysis. However, from our light gbm model, we did see that the team categorical feature was a top 3 feature when predicting a winner. Thus, we cannot drop the team column despite our model being at the player-performance level.

# %%
X = pd.get_dummies(X, columns=['team', 'conference'], drop_first=False).astype(int)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233734 entries, 0 to 233733
# Data columns (total 89 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   season                            233734 non-null  int64
#  1   week                              233734 non-null  int64
#  2   games_played_this_week            233734 non-null  int64
#  3   numMinutes                        233734 non-null  int64
#  4   points                            233734 non-null  int64
#  5   assists                           233734 non-null  int64
#  6   blocks                            233734 non-null  int64
#  7   steals                            233734 non-null  int64
#  8   reboundsTotal                     233734 non-null  int64
#  9   reboundsDefensive                 233734 non-null  int64
#  10  reboundsOffensive                 233734 non-null  int64
#  11  fieldGoalsAttempted               233734 non-null  int64
#  12  fieldGoalsMade                    233734 non-null  int64
#  13  threePointersAttempted            233734 non-null  int64
#  14  threePointersMade                 233734 non-null  int64
#  15  freeThrowsAttempted               233734 non-null  int64
#  16  freeThrowsMade                    233734 non-null  int64
#  17  turnovers                         233734 non-null  int64
#  18  foulsPersonal                     233734 non-null  int64
#  19  plusMinusPoints                   233734 non-null  int64
#  20  wins_this_week                    233734 non-null  int64
#  21  wins_vs_team_with_all_nba_player  233734 non-null  int64
#  22  avg_opp_score                     233734 non-null  int64
#  23  avg_opp_winrate_prior             233734 non-null  int64
#  24  avg_opp_wins_prior                233734 non-null  int64
#  25  avg_opp_losses_prior              233734 non-null  int64
#  26  away_games_prior                  233734 non-null  int64
#  27  away_losses_prior                 233734 non-null  int64
#  28  away_win_streak_prior             233734 non-null  int64
#  29  away_wins_prior                   233734 non-null  int64
#  30  home_games_prior                  233734 non-null  int64
#  31  home_losses_prior                 233734 non-null  int64
#  32  home_win_streak_prior             233734 non-null  int64
#  33  home_wins_prior                   233734 non-null  int64
#  34  losses_prior                      233734 non-null  int64
#  35  wins_vs_over_500_prior            233734 non-null  int64
#  36  team_pts                          233734 non-null  int64
#  37  team_ast                          233734 non-null  int64
#  38  team_blk                          233734 non-null  int64
#  39  team_stl                          233734 non-null  int64
#  40  team_gms                          233734 non-null  int64
#  41  fieldGoalsPercentage              233734 non-null  int64
#  42  threePointersPercentage           233734 non-null  int64
#  43  freeThrowsPercentage              233734 non-null  int64
#  44  points_mean_season                233734 non-null  int64
#  45  points_std_season                 233734 non-null  int64
#  46  assists_mean_season               233734 non-null  int64
#  47  assists_std_season                233734 non-null  int64
#  48  plusMinusPoints_mean_season       233734 non-null  int64
#  49  plusMinusPoints_std_season        233734 non-null  int64
#  50  z_pts                             233734 non-null  int64
#  51  z_ast                             233734 non-null  int64
#  52  z_pm                              233734 non-null  int64
#  53  breakout_score                    233734 non-null  int64
#  54  team_76ers                        233734 non-null  int64
#  55  team_Bobcats                      233734 non-null  int64
#  56  team_Bucks                        233734 non-null  int64
#  57  team_Bullets                      233734 non-null  int64
#  58  team_Bulls                        233734 non-null  int64
#  59  team_Cavaliers                    233734 non-null  int64
#  60  team_Celtics                      233734 non-null  int64
#  61  team_Clippers                     233734 non-null  int64
#  62  team_Grizzlies                    233734 non-null  int64
#  63  team_Hawks                        233734 non-null  int64
#  64  team_Heat                         233734 non-null  int64
#  65  team_Hornets                      233734 non-null  int64
#  66  team_Jazz                         233734 non-null  int64
#  67  team_Kings                        233734 non-null  int64
#  68  team_Knicks                       233734 non-null  int64
#  69  team_Lakers                       233734 non-null  int64
#  70  team_Magic                        233734 non-null  int64
#  71  team_Mavericks                    233734 non-null  int64
#  72  team_Nets                         233734 non-null  int64
#  73  team_Nuggets                      233734 non-null  int64
#  74  team_Pacers                       233734 non-null  int64
#  75  team_Pelicans                     233734 non-null  int64
#  76  team_Pistons                      233734 non-null  int64
#  77  team_Raptors                      233734 non-null  int64
#  78  team_Rockets                      233734 non-null  int64
#  79  team_Spurs                        233734 non-null  int64
#  80  team_Suns                         233734 non-null  int64
#  81  team_SuperSonics                  233734 non-null  int64
#  82  team_Thunder                      233734 non-null  int64
#  83  team_Timberwolves                 233734 non-null  int64
#  84  team_Trail Blazers                233734 non-null  int64
#  85  team_Warriors                     233734 non-null  int64
#  86  team_Wizards                      233734 non-null  int64
#  87  conference_East                   233734 non-null  int64
#  88  conference_West                   233734 non-null  int64
# dtypes: int64(89)
# memory usage: 158.7 MB

# %%
X.head()
# Out:
#    season  week  ...  conference_East  conference_West
# 0    1983    46  ...                0                1
# 1    1983    47  ...                0                1
# 2    1983    48  ...                0                1
# 3    1983    50  ...                0                1
# 4    1983    52  ...                0                1
#
# [5 rows x 89 columns]

# %% [markdown]
# Let's now visualize the distribution of some of our top features from our light gbm model. Even though these features might not be statisically significant for our future regression models, since there are so many features, lets choose to examine them to get some idea of our data scale.

# %%
# Not including team feature as we 1 hot encoded it
top_features = ['points', 'wins_this_week', 'team_pts', 'fieldGoalsMade', 'fieldGoalsPercentage', 'plusMinusPoints', 'assists', 'reboundsTotal', 'team_gms']
plt.figure(figsize=(18, 18))
for i, feat in enumerate(top_features):
    plt.subplot(3, 3, i+1)
    sns.histplot(X[feat], kde=True)
    plt.title(f"{feat} KDE")
    plt.tight_layout

# %% [markdown]
# As we can see, our scale varies with our selected features, and it can be assumed to be the same case with the rest of the features in our data. Since PCA moves in the direction of maximum variance, a feature with a greater max value will heavily skew the analysis when compared to other features with a lower range. In other words, PCA will believe that features with greater max values are much more important when scaling the number of componenets. As such, we will scale our features using Standard Scaler as it will allow our feature distributions to be normal i.e. each feature has equal weight.

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Principal Component Analysis

# %%
pca = PCA(n_components=50)
pca.fit(X_scaled)
# Out:
# PCA(n_components=50)

# %%
cum_var = np.cumsum(pca.explained_variance_ratio_)
opt_components = 0
for i, val in enumerate(cum_var):
    if val > 0.8:
        opt_components = i - 1
        break

# %%
fig = plt.figure(figsize=(10, 6))
x = np.arange(1, len(cum_var) + 1)
x_tick = np.arange(1, len(cum_var) + 1, 2)
plt.axhline(y=0.8, color='red', linestyle='--', label='80% Threshold')
plt.plot(x, cum_var, label="c.EVR")
plt.scatter([opt_components + 1], [cum_var[opt_components]], label=f"Optimal: {opt_components + 1}", marker="x", color="green")
plt.title("Cumulative Explained Variance Ratio (c.EVR) vs. Number of Components")
plt.figtext(0.1, 0.01, f"Original Feature Count: {len(X.columns)}", fontsize=10, color="black")
plt.xticks(x_tick)
plt.legend()
plt.ylabel("c.EVR")
plt.xlabel("Number of Components");

# %% [markdown]
# We will be using an 80% explained variance, we have reduced our feature count of 89 to 38 components that explain 80% of the variance of our features. Given this optimal number of components, lets run our final PCA.

# %%
final_pca = PCA(n_components=38)
X_pca = final_pca.fit_transform(X_scaled)
comp = [f"Component_{i}" for i in range(1, 39)]
vars = final_pca.explained_variance_
pca_df = pd.DataFrame([vars], columns=comp)
pca_df
# Out:
#    Component_1  Component_2  ...  Component_37  Component_38
# 0    13.823291     7.618931  ...      1.019628      1.018675
#
# [1 rows x 38 columns]
